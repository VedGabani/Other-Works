# %% [markdown]
# # Q-6

# %% [markdown]
# This code is used for marks greater than 75 using mask function

# %%
import numpy as np

# %%
marks = np.array([45,67,89,32,90,76,55,99,41,68])

mask = marks > 60

print("Filtered Marks -_- ", marks[mask])
