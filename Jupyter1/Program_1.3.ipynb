# %% [markdown]
# # Q-3

# %% [markdown]
# This program is used find highest and lowest number using max and min function

# %%
import numpy as np

# %%
marks = np.array([45,67,89,32,90,76,55,99,41,68])

print("Max Marks -_- ", np.max(marks))
print("Min Marks -_- ", np.min(marks))
