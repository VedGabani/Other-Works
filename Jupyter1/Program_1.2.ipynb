# %% [markdown]
# # Q-2

# %% [markdown]
# This program is used to find mean of an array using mean function

# %%
import numpy as np

marks = np.array([45,67,89,32,90,76,55,99,41,68])

print("Marks -_- ", np.mean(marks))
# Out:
# Marks -_-  66.2
