# %% [markdown]
# # Q-4

# %% [markdown]
# This code is used to sort marks in ascending order using sort function

# %%
import numpy as np

# %%
marks = np.array([45,67,89,32,90,76,55,99,41,68])

print("sorted marks -_- ", np.sort(marks))
# Out:
# sorted marks -_-  [32 41 45 55 67 68 76 89 90 99]
