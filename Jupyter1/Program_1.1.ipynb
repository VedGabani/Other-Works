# %% [markdown]
# # Q-1

# %% [markdown]
# This Program is used to find sum of marks from the array using sum function

# %%
import numpy as np

marks = np.array([45,67,89,32,90,76,55,99,41,68])

print("Marks -_- ", np.sum(marks))
# Out:
# Marks -_-  662
