# %% [markdown]
# # Q-5

# %% [markdown]
# This program is used display number greater than 60 using greater function

# %%
import numpy as np

# %%
marks = np.array([45,67,89,32,90,76,55,99,41,68])

print("Filtered marks -_- ", marks[marks > 60])
# Out:
# Filtered marks -_-  [67 89 90 76 99 68]
