# %% [markdown]
# # Q-9

# %% [markdown]
# This code is used to split array in 2 equal part using split method

# %%
import numpy as np

# %%
marks = np.array([45,67,89,32,90,76,55,99,41,68])

print("Split marks -_- ", np.split(marks, 2))
# Out:
# Split marks -_-  [array([45, 67, 89, 32, 90]), array([76, 55, 99, 41, 68])]
