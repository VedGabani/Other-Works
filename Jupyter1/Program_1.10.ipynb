# %% [markdown]
# # Q-10

# %% [markdown]
# This program is used to find index number using index function

# %%
import numpy as np

# %%
marks = np.array([45,67,89,32,90,76,55,99,41,68])

print("Index of 90 -_- ", np.where(marks == 90))
# Out:
# Index of 90 -_-  (array([4]),)
