# %% [markdown]
# # Q-8

# %% [markdown]
# This program is used to broadcasting marks using Broadcast method

# %%
import numpy as np

# %%
a = np.array([[5]])
marks = np.array([45,67,89,32,90,76,55,99,41,68])

print("BaseException -_- ", a + marks)
