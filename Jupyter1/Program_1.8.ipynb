# %% [markdown]
# # Q-8

# %% [markdown]
# This program is used to broadcasting marks using Broadcast method

# %%
import numpy as np

# %%
a = np.array([[1],[2],[3]])
b = np.array([10,20,30])

print("BaseException -_- ", a + b)
# Out:
# BaseException -_-  [[11 21 31]
#  [12 22 32]
#  [13 23 33]]
