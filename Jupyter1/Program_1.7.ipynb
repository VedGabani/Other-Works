# %% [markdown]
# # Q-7

# %% [markdown]
# greating a new array using reshape function

# %%
import numpy as np

# %%
marks = np.array([45,67,89,32,90,76,55,99,41,68])

print("Reshaped marks -_- ", np.reshape(marks, (2,5)))
# Out:
# Reshaped marks -_-  [[45 67 89 32 90]
#  [76 55 99 41 68]]
